# %% [markdown]
# <a href="https://colab.research.google.com/github/uvsq22003112/l1-python/blob/master/Copie_de_Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
1 + 1
# Out:
# 2

# %%
a= 1 + 1

# %%
a

# %%
print (a)
# Out:
# 2

# %%
a=2
b=1
print(a+b)
# Out:
# 3

# %%
a=5
b=2
print(a, b)
# Out:
# 5 2

# %%
(a, b)
# Out:
# (5, 2)

# %%
print(a)
print(b)
# Out:
# 5
# 2

# %%
print("a vaut", a, "et b vaut", b)
# Out:
# a vaut 5 et b vaut 2

# %%
a="hello world"
print(a)
a
# Out:
# hello world
# 'hello world'
